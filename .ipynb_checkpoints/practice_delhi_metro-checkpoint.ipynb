# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import folium
from folium.plugins import HeatMap
from haversine import haversine

# %%
df = pd.read_csv('Delhi Metro.csv')
df
# Out:
#      ID (Station ID)                 Station Names  \
# 0                1.0  Shaheed Sthal(First Station)
# 1                2.0                  Hindon River
# 2                3.0                       Arthala
# 3                4.0                   Mohan Nagar
# 4                5.0                    Shyam park
# ..               ...                           ...
# 333              NaN                    Conn: Pink
# 334              4.0                Delhi Aerocity
# 335              5.0                   IGI Airport
# 336              6.0              Dwarka Sector 21
# 337              NaN                    Conn: Blue
#
#      Dist. From First Station(km)   Metro Line Opened(Year)       Layout  \
# 0                             0.0     Red line   08-03-2019     Elevated
# 1                             1.0     Red line   08-03-2019     Elevated
# 2                             2.5     Red line   08-03-2019     Elevated
# ...

# %%
df= df.dropna()
df
# Out:
#      ID (Station ID)                 Station Names  \
# 0                1.0  Shaheed Sthal(First Station)
# 1                2.0                  Hindon River
# 2                3.0                       Arthala
# 3                4.0                   Mohan Nagar
# 4                5.0                    Shyam park
# ..               ...                           ...
# 331              2.0               Shivaji Stadium
# 332              3.0                   Dhaula Kuan
# 334              4.0                Delhi Aerocity
# 335              5.0                   IGI Airport
# 336              6.0              Dwarka Sector 21
#
#      Dist. From First Station(km)   Metro Line Opened(Year)       Layout  \
# 0                             0.0     Red line   08-03-2019     Elevated
# 1                             1.0     Red line   08-03-2019     Elevated
# 2                             2.5     Red line   08-03-2019     Elevated
# ...

# %% [markdown]
# feature 1 : Station and Route Heatmaps

# %%
delhi_center = [28.6139, 77.2090]
m = folium.Map(location=delhi_center, zoom_start=11)

# %%
heat_data = df[["Latitude", "Longitude"]].values.tolist()

# %%
HeatMap(heat_data, radius=12, blur=18, min_opacity=0.4).add_to(m)
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row["Latitude"], row["Longitude"]],
        radius=3,
        color="orange",
        fill=True,
        fill_color="orange",
        popup=row["Station Names"]
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# feature 2 : popular stations

# %%
df.loc[:, "Usage"] = (1000 / (df["Dist. From First Station(km)"] + 1)) + np.random.randint(50, 500, len(df))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14288\3491936601.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, "Usage"] = (1000 / (df["Dist. From First Station(km)"] + 1)) + np.random.randint(50, 500, len(df))

# %%
df = df.copy()
df["Rank"] = df["Usage"].rank(ascending=False)
top_stations = df.sort_values("Usage", ascending=False).head(10)

# %%
df
# Out:
#      ID (Station ID)                 Station Names  \
# 0                1.0  Shaheed Sthal(First Station)
# 1                2.0                  Hindon River
# 2                3.0                       Arthala
# 3                4.0                   Mohan Nagar
# 4                5.0                    Shyam park
# ..               ...                           ...
# 331              2.0               Shivaji Stadium
# 332              3.0                   Dhaula Kuan
# 334              4.0                Delhi Aerocity
# 335              5.0                   IGI Airport
# 336              6.0              Dwarka Sector 21
#
#      Dist. From First Station(km)   Metro Line Opened(Year)       Layout  \
# 0                             0.0     Red line   08-03-2019     Elevated
# 1                             1.0     Red line   08-03-2019     Elevated
# 2                             2.5     Red line   08-03-2019     Elevated
# ...

# %%
print("Top 10 Most Popular Stations:")
display(top_stations[["Station Names", "Metro Line", "Usage", "Rank"]])
# Out:
# Top 10 Most Popular Stations:
#                        Station Names        Metro Line   Usage  Rank
# 173                    Sector 55-66        Rapid Metro  1490.0   1.0
# 33     Samaypur Badli(First Station)       Yellow line  1414.0   2.0
# 79   Dwarka Sector 21(First station)         Blue line  1402.0   3.0
# 185                    Kashmere Gate       Voilet line  1395.0   4.0
# 303                  Noida Sector 51         Aqua line  1335.0   5.0
# 329        New Delhi-Airport Express       Orange line  1327.0   6.0
# 226                  Janak Puri West      Magenta line  1269.0   7.0
# 152                Inderlok Conn:Red        Green line  1210.0   8.0
# 0       Shaheed Sthal(First Station)          Red line  1195.0   9.0
# 138                      Yamuna Bank  Blue line branch  1160.0  10.0

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_stations["Station Names"], top_stations["Usage"], color='pink')
plt.xticks(rotation = 45, ha="right")
plt.xlabel("Popularity Score")
plt.ylabel("Station Name")
plt.title("Top 10 Popular Delhi Metro Stations")
plt.grid(axis='y', linestyle='-', alpha=0.7)
plt.show()

# %%
df
# Out:
#      ID (Station ID)                 Station Names  \
# 0                1.0  Shaheed Sthal(First Station)
# 1                2.0                  Hindon River
# 2                3.0                       Arthala
# 3                4.0                   Mohan Nagar
# 4                5.0                    Shyam park
# ..               ...                           ...
# 331              2.0               Shivaji Stadium
# 332              3.0                   Dhaula Kuan
# 334              4.0                Delhi Aerocity
# 335              5.0                   IGI Airport
# 336              6.0              Dwarka Sector 21
#
#      Dist. From First Station(km)   Metro Line Opened(Year)       Layout  \
# 0                             0.0     Red line   08-03-2019     Elevated
# 1                             1.0     Red line   08-03-2019     Elevated
# 2                             2.5     Red line   08-03-2019     Elevated
# ...

# %% [markdown]
# feature 5 :station to station travel time

# %%
routes_data = []

# Ensure data validity
df = df.dropna(subset=["Latitude", "Longitude"])

# Group by Metro Line (if only one exists, it still works)
for line, group in df.groupby("Metro Line"):
    group = group.sort_values(by=["Dist. From First Station(km)", "Latitude"]).reset_index(drop=True)
    
    # Calculate route distances between consecutive stations
    for i in range(len(group) - 1):
        s1 = group.loc[i]
        s2 = group.loc[i + 1]

        if pd.notna(s1["Latitude"]) and pd.notna(s2["Latitude"]):
            distance_km = haversine(
                (s1["Latitude"], s1["Longitude"]),
                (s2["Latitude"], s2["Longitude"])
            )

            # Randomized usage score (more realistic scaling)
            usage_score = np.random.uniform(500, 1500) / (distance_km + 0.5)

            routes_data.append({
                "Metro Line": line,
                "From Station": s1["Station Names"],
                "To Station": s2["Station Names"],
                "Distance (km)": round(distance_km, 2),
                "Usage Score": round(usage_score, 2)
            })

# Convert to DataFrame
routes_df = pd.DataFrame(routes_data)

# If less than 10 real routes exist, fill with simulated placeholders
if len(routes_df) < 10:
    print(f"⚠️ Only {len(routes_df)} real routes found — adding simulated entries to make Top 10.")
    for i in range(len(routes_df), 10):
        routes_df.loc[i] = [
            "Simulated Line",
            f"Station_{i}",
            f"Station_{i+1}",
            round(np.random.uniform(1.0, 10.0), 2),
            round(np.random.uniform(200, 1500), 2)
        ]

# Sort by usage score
top_routes = routes_df.sort_values("Usage Score", ascending=False).head(10)

print("\n🏆 Top 10 Most Used Routes (Haversine-Based or Simulated):")
display(top_routes)

# -------------------------------
# Visualization: Top 10 Routes
# -------------------------------
plt.figure(figsize=(10, 6))
plt.bar(top_routes["From Station"] + " → " + top_routes["To Station"], 
        top_routes["Usage Score"], color='blue')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Route")
plt.ylabel("Usage Score")
plt.title("Top 10 Most Used Delhi Metro Routes (Haversine or Simulated)")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 🏆 Top 10 Most Used Routes (Haversine-Based or Simulated):
#       Metro Line           From Station         To Station  Distance (km)  \
# 167  Rapid Metro           Sector 53-54       Sector 42-43            0.0
# 66     Blue line        Noida Sector 61    Noida Sector 59            0.0
# 67     Blue line        Noida Sector 59    Noida Sector 62            0.0
# 65     Blue line        Noida Sector 52    Noida Sector 61            0.0
# 171  Rapid Metro           DLF Phase 2   Belvedere Towers             0.0
# 168  Rapid Metro           Sector 42-43       DLF Phase 1             0.0
# 166  Rapid Metro       Sector 54 Chowk        Sector 53-54            0.0
# 18     Aqua line  Delta 1 Greater Noida       GNIDA Office            0.0
# 170  Rapid Metro           Sikandarpur        DLF Phase 2             0.0
# 172  Rapid Metro      Belvedere Towers         Cyber City             0.0
#
#      Usage Score
# 167      2923.23
# 66       2811.08
# 67       2670.75
# 65       2504.26
# ...

# %% [markdown]
# feature 7 : Count total users & sessions per city

# %%
np.random.seed(42)
city_data = (
    df.groupby("Metro Line")
    .agg({
        "Station Names": "count"
    })
    .rename(columns={"Station Names": "Total Stations"})
    .reset_index()
)

# %%
city_data["Total Users"] = np.random.randint(10000, 80000, len(city_data))
city_data["Total Sessions"] = np.random.randint(20000, 150000, len(city_data))

# %%
city_data["Avg Sessions/User"] = (city_data["Total Sessions"] / city_data["Total Users"]).round(2)

# %%
city_data
# Out:
#            Metro Line  Total Stations  Total Users  Total Sessions  \
# 0           Aqua line              21        25795           82955
# 1           Blue line              49        10860           84925
# 2    Blue line branch               8        64886          141637
# 3           Gray line               3        16265           87969
# 4          Green line              21        47194           25311
# 5   Green line branch               3        54131          123355
# 6        Magenta line              25        70263          124724
# 7         Orange line               6        26023          103104
# 8           Pink line              38        51090           73707
# 9         Rapid Metro              11        77221          105305
# 10           Red line              28        74820           48693
# 11        Voilet line              34        10769           91932
# 12        Yellow line              37        69735          147723
#
#     Avg Sessions/User
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(city_data["Metro Line"], city_data["Total Users"], color="royalblue")
plt.xticks(rotation = 45, ha = "right")
plt.xlabel("City / Metro Line")
plt.ylabel("Total Users")
plt.title("Total Users per City")
plt.grid(axis='y', linestyle='-', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(city_data["Metro Line"], city_data["Total Sessions"], color="teal")
plt.xticks(rotation = 45, ha = "right")
plt.xlabel("City / Metro Line")
plt.ylabel("Total Sessions")
plt.title("Total Sessions per City")
plt.grid(axis='y', linestyle='-', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(city_data["Metro Line"], city_data["Avg Sessions/User"], color="mediumseagreen")
plt.xticks(rotation = 45, ha = "right")
plt.xlabel("City / Metro Line")
plt.ylabel("Avg Sessions per User")
plt.title("Average Sessions per User by City")
plt.grid(axis='y', linestyle='-', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# feature 3 : peak hour analysis

# %%
np.random.seed(42)

# %%
hours = list(range(0, 24))
station_names = df["Station Names"].unique()

# %%
data = []
for station in station_names:
    for hour in hours:
        base = np.random.randint(20, 100)
        if 7 <= hour <= 10 or 17 <= hour <= 20:
            base += np.random.randint(200, 400)
        data.append([station, hour, base])

# %%
peak_df = pd.DataFrame(data, columns=["Station Name", "Hour", "Passenger Count"])

# %%
peak_hour_per_station = (
peak_df[["Station Name", "Passenger Count"]].groupby("Station Name", group_keys=False).apply(lambda x: x.loc[x["Passenger Count"].idxmax()]).reset_index(drop=True))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14288\2469859389.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   peak_df[["Station Name", "Passenger Count"]].groupby("Station Name", group_keys=False).apply(lambda x: x.loc[x["Passenger Count"].idxmax()]).reset_index(drop=True))

# %%
sample_station = np.random.choice(station_names)
station_data = peak_df[peak_df["Station Name"] == sample_station]

plt.figure(figsize=(10, 5))
plt.plot(station_data["Hour"], station_data["Passenger Count"], marker='o', color="royalblue")
plt.title(f"Hourly Passenger Trend — {sample_station}")
plt.xlabel("Hour of Day")
plt.ylabel("Passenger Count")
plt.grid(alpha=0.4)
plt.xticks(range(0, 24))
plt.tight_layout()
plt.show()

# %%
top10_peak = peak_hour_per_station.sort_values("Passenger Count", ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.bar(top10_peak["Station Name"], top10_peak["Passenger Count"], color="tan")
plt.xlabel("Stations")
plt.ylabel("Peak Hour ")
plt.title("Top 10 Stations by Peak Hour Passenger Load")
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# feature 4 : user Retention

# %%
# making of 1 month of the data !
np.random.seed(42)
num_users = 200
days = pd.date_range(start="2025-09-01", end="2025-09-30")

# %%
user_sessions = []
for user in range(1, num_users + 1):
    num_sessions = np.random.randint(2, 20)
    active_days = np.random.choice(days, num_sessions, replace=False)
    for d in active_days:
        user_sessions.append([user, d])

df = pd.DataFrame(user_sessions, columns=["User_ID", "Session_Date"])

# %%
daily_active = df.groupby("Session_Date")["User_ID"].nunique().reset_index()
daily_active.columns = ["Date", "Active_Users"]

# %%
user_activity_counts = retention_df.groupby("User_ID")["Session_Date"].nunique().reset_index()
user_activity_counts.columns = ["User_ID", "Active_Days"]

# %%
retention_rate = (user_activity_counts["Active_Days"] > 3).sum() / len(user_activity_counts) * 100

# %%
plt.figure(figsize=(9, 7))
plt.plot(daily_active["Date"], daily_active["Active_Users"], color="blue", marker='*')
plt.xticks(rotation = 45, ha = 'right')
plt.title("Daily Active Users")
plt.xlabel("Date")
plt.ylabel("Active Users")
plt.tight_layout()
plt.show()

# %%
df
# Out:
#       User_ID Session_Date
# 0           1   2025-09-10
# 1           1   2025-09-19
# 2           1   2025-09-15
# 3           1   2025-09-11
# 4           1   2025-09-18
# ...       ...          ...
# 2262      200   2025-09-08
# 2263      200   2025-09-23
# 2264      200   2025-09-24
# 2265      200   2025-09-13
# 2266      200   2025-09-19
#
# [2267 rows x 2 columns]
